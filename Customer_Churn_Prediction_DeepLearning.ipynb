# %% [markdown]
# # Customer Churn Prediction using machine learning

# %% [markdown]
# Customer churn prediction is to measure why customers are leaving a business. In this tutorial we will be looking at customer churn in telecom business. We will build a deep learning model to predict the churn and use precision,recall, f1-score to measure performance of our model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
df = pd.read_csv('Customer_churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# First of all, drop customer Id..

# %%
df.drop('customerID',axis=1,inplace=True)

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# ###### TotalCharges should be float but it is an object. Let's check what's going on with this column

# %%
df['TotalCharges'].values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %% [markdown]
# ###### Oops!!!! above values are strings.

# %%
pd.to_numeric(df['TotalCharges'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\KAMALS~1\AppData\Local\Temp/ipykernel_2096/4092668822.py in <module>
# ----> 1 pd.to_numeric(df['TotalCharges'])
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
#     184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#
# ...

# %%
pd.to_numeric(df.TotalCharges, errors = 'coerce').isnull().sum()
# Out:
# 11

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
df['TotalCharges'][488]
# Out:
# ' '

# %% [markdown]
# ##### Drop the rows which have null strings in TotalCharges Column

# %%
df_new = df[df['TotalCharges'] != ' ']

# %%
df_new.shape
# Out:
# (7032, 20)

# %% [markdown]
# ##### Now convert object values of TotalCharges into float

# %%
df_new['TotalCharges'] = pd.to_numeric(df_new['TotalCharges'])
# Out:
# C:\Users\KAMALS~1\AppData\Local\Temp/ipykernel_2096/861564446.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['TotalCharges'] = pd.to_numeric(df_new['TotalCharges'])

# %%
df_new.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
tenure_churn_yes = df[df.Churn == 'Yes'].tenure
tenure_churn_no = df[df.Churn == 'No'].tenure

plt.xlabel("Tenure")
plt.ylabel("Number of Customers")

plt.hist([tenure_churn_yes,tenure_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
def printunique(df):
    for column in df:
        if df[column].dtypes == 'object':
            print(f'{column}: {df[column].unique()}')

# %%
printunique(df_new)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
df_new.replace('No internet service','No',inplace=True)
df_new.replace('No phone service','No',inplace=True)

# %%
printunique(df_new)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %% [markdown]
# ##### Convert Yes to 1 , No to 0  and Female to 1 , Male to 0

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport',
                 'StreamingTV','StreamingMovies','PaperlessBilling','Churn']

for col in yes_no_columns:
    df_new[col].replace({'Yes': 1,'No': 0},inplace=True)

# %%
df_new.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0  Female              0        1           0       1             0
# 1    Male              0        0           0      34             1
# 2    Male              0        0           0       2             1
# 3    Male              0        0           0      45             0
# 4  Female              0        0           0       2             1
#
#    MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 0              0             DSL               0             1
# 1              0             DSL               1             0
# 2              0             DSL               1             1
# 3              0             DSL               1             0
# 4              0     Fiber optic               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0                 0            0            0                0
# ...

# %%
df_new['gender'].replace({'Female':1, 'Male':0},inplace=True)

# %%
df_new.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       1              0        1           0       1             0
# 1       0              0        0           0      34             1
# 2       0              0        0           0       2             1
# 3       0              0        0           0      45             0
# 4       1              0        0           0       2             1
#
#    MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 0              0             DSL               0             1
# 1              0             DSL               1             0
# 2              0             DSL               1             1
# 3              0             DSL               1             0
# 4              0     Fiber optic               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0                 0            0            0                0
# ...

# %% [markdown]
# ##### Now use One-hot encoding for categorical columns,which have more than two category.

# %%
df_1 = pd.get_dummies(data = df_new, columns = ['InternetService','Contract','PaymentMethod'])

# %%
df_1.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       1              0        1           0       1             0
# 1       0              0        0           0      34             1
# 2       0              0        0           0       2             1
# 3       0              0        0           0      45             0
# 4       1              0        0           0       2             1
#
#    MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  \
# 0              0               0             1                 0            0
# 1              0               1             0                 1            0
# 2              0               1             1                 0            0
# 3              0               1             0                 1            1
# 4              0               0             0                 0            0
#
#    StreamingTV  StreamingMovies  PaperlessBilling  MonthlyCharges  \
# ...

# %% [markdown]
# ### Now we have all numerical columns

# %% [markdown]
# ##### Now scale out data using MinMaxscaler

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
col_for_scale = ['tenure','MonthlyCharges','TotalCharges'] 
df_1[col_for_scale] = scaler.fit_transform(df_1[col_for_scale])

# %%
df_1.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0       1              0        1           0  0.000000             0
# 1       0              0        0           0  0.464789             1
# 2       0              0        0           0  0.014085             1
# 3       0              0        0           0  0.619718             0
# 4       1              0        0           0  0.014085             1
#
#    MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  \
# 0              0               0             1                 0            0
# 1              0               1             0                 1            0
# 2              0               1             1                 0            0
# 3              0               1             0                 1            1
# 4              0               0             0                 0            0
#
#    StreamingTV  StreamingMovies  PaperlessBilling  MonthlyCharges  \
# ...

# %%
X = df_1.drop('Churn',axis=1)
y = df_1.Churn

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2, random_state=5)

# %%
print(len(X_train))
print(len(X_test))
print(len(y_train))
print(len(y_test))
# Out:
# 5625
# 1407
# 5625
# 1407

# %% [markdown]
# # Now Build Model

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([
    keras.layers.Dense(26, input_shape=(26,),activation = 'relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(6, activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
             metrics = ['accuracy'])

# %%
model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3972 - accuracy: 0.8123
# Epoch 2/50
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3966 - accuracy: 0.8149
# Epoch 3/50
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3947 - accuracy: 0.8148
# Epoch 4/50
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3933 - accuracy: 0.8164
# Epoch 5/50
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3945 - accuracy: 0.8156
# Epoch 6/50
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3915 - accuracy: 0.8149
# Epoch 7/50
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3917 - accuracy: 0.8167
# Epoch 8/50
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3891 - accuracy: 0.8149
# Epoch 9/50
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3874 - accuracy: 0.8196
# Epoch 10/50
# ...

# %%
model.evaluate(X_test, y_test)
# Out:
# 44/44 [==============================] - 0s 2ms/step - loss: 0.4681 - accuracy: 0.7783
# [0.46808183193206787, 0.778251588344574]

# %%
y_predict = model.predict(X_test)

# %%
y_pred = []
for element in y_predict:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
y_pred[:10]
# Out:
# [0, 1, 0, 1, 0, 1, 0, 0, 0, 0]

# %%
y_test[:10]
# Out:
# 2660    0
# 744     0
# 5579    1
# 64      1
# 3287    1
# 816     1
# 2670    0
# 5920    0
# 1023    0
# 6087    0
# Name: Churn, dtype: int64

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85       999
#            1       0.64      0.53      0.58       408
#
#     accuracy                           0.78      1407
#    macro avg       0.73      0.71      0.72      1407
# weighted avg       0.77      0.78      0.77      1407

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
